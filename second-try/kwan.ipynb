# %% [markdown]
# kwan 모델을 위한 데이터 만들기
#
# - kwan_num
# - kwan_name
#
# ? kwan_image

# %%
import pandas as pd

# %%
csv = pd.read_csv('classes.csv')

# %%
data = csv.drop(csv.columns[0], axis=1)

# %%
data
# Out:
#     kind     code   class_name prof   room date1 date2  start    end kwan_name
# 0     교선  AK00021           요가  정은송  5C301     금   NaN  10:00  10:50       나눔관
# 1     교선  AK00021           요가  정은송  5C301     금   NaN  11:00  11:50       나눔관
# 2     교선  AD00164        생활과발레  장소정  5C301     목   NaN  10:00  11:50       나눔관
# 3     전탐  VM00002    커뮤니케이션의이해  김서중   M205     월   NaN  15:00  17:50      미가엘관
# 4     전탐  VS00012    경제환경과기업경영   이웅   M205     화   NaN  15:00  17:50      미가엘관
# ..   ...      ...          ...  ...    ...   ...   ...    ...    ...       ...
# 387   전탐  VI00016    Java프로그래밍  이하규   6406     월     수  16:30  17:45     정보과학관
# 388   전선  XC00008        디지털통신  정인철   6406     월     수  13:30  14:45     정보과학관
# 389   전선  XC00033      사물인터넷응용  정인철   6406     월   NaN  09:00  11:50     정보과학관
# 390   전탐  VI00007      사물인터넷기초  유상신   6406     화     목  15:00  16:15     정보과학관
# 391   전선  XB00039  사물인터넷캡스톤디자인  유상신   6406     화   NaN  09:00  11:50     정보과학관
#
# [392 rows x 10 columns]

# %%
data = data['']
