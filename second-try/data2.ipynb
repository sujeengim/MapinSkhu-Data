# %%
import pandas as pd

# %%
csv = pd.read_csv('data1.csv')

# %%
csv
# Out:
#      Unnamed: 0 kind     code           class_name prof  \
# 0             0   교필  AK00055  비아메디아채플(나와 타인 이해하기)  이남호
# 1             1   교필  AK00055     비아메디아채플(리더십의 영성)  김한승
# 2             2   교필  AK00055       비아메디아채플(서양음악사)  박태영
# 3             3   교필  AK00055      비아메디아채플(성공회이야기)  노철래
# 4             4   교필  AK00055      비아메디아채플(시각과 영성)  김돈회
# ..          ...  ...      ...                  ...  ...
# 413         413   전선  XE00003             데이터기초수학2  백지현
# 414         414   전선  XE00004               고급머신러닝  홍성준
# 415         415   전선  XE00005        고급Python프로그래밍  홍성준
# 416         416   전선  XE00006             딥러닝프레임워크  이상윤
# 417         417   전선  XE00007              확률과랜덤변수  이상윤
#
#                                           room_time
# 0                            1505 / 월 / 11:00~11:50
# 1                            3501 / 월 / 11:00~11:50
# 2                            M301 / 월 / 11:00~11:50
# 3                            3301 / 목 / 11:00~11:50
# ...

# %%
type(csv)
# Out:
# pandas.core.frame.DataFrame
